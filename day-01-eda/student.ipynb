# %% [markdown]
# # Day 1 — Student lab
#
# Use the synthetic data dictionary. Explain each decision. Complete Tasks 1–6; then write a three-sentence briefing: finding, limitation, next step.
#
# For timed pair activities and expected checks, open TASK_CARDS.md. Swap keyboard and explanation roles regularly.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
candidates = [Path.cwd(), *Path.cwd().parents]
ROOT = next((p for p in candidates if (p / 'datasets/retail_orders.csv').exists()), None)
if ROOT is None:
    raise FileNotFoundError('Open the notebook inside the downloaded repository.')
raw = pd.read_csv(ROOT / 'datasets/retail_orders.csv')
print(raw.head().to_string(index=False))
print('Rows and columns:', raw.shape)
raw.info()

# %% [markdown]
# ## 2. Audit the data before changing it
#
# Use the corresponding section of the teaching guide for requirements. Record your reasoning alongside the code.

# %%
# Write your solution here.

# %% [markdown]
# ## 3. Apply documented cleaning rules
#
# Use the corresponding section of the teaching guide for requirements. Record your reasoning alongside the code.

# %%
# Write your solution here.

# %% [markdown]
# ## 4. Summarise distributions and channels
#
# Use the corresponding section of the teaching guide for requirements. Record your reasoning alongside the code.

# %%
# Write your solution here.

# %% [markdown]
# ## 5. Plot distributions and comparisons
#
# Use the corresponding section of the teaching guide for requirements. Record your reasoning alongside the code.

# %%
# Write your solution here.

# %% [markdown]
# ## 6. Flag unusual observations for review
#
# Use the corresponding section of the teaching guide for requirements. Record your reasoning alongside the code.

# %%
# Write your solution here.

# %% [markdown]
# ## Management briefing
#
# Which channel has more recorded revenue? Does it have more orders or higher order values? How do missing prices and the bulk order affect your interpretation?
#
# Extension: compare mean and median, and run a labelled sensitivity analysis excluding the bulk order.
